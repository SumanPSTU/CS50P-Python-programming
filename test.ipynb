# %%
import  sys
if len(sys.argv)<2:
    sys.exit("Too many argument!")
for agv in sys.argv[1:]:
    print("Hello,",agv)
# Out:
# Hello, -f
# Hello, /root/.local/share/jupyter/runtime/kernel-480a8d68-d68d-47db-9319-e232edd06ea7.json
